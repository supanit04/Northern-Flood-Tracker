# %%
import pandas as pd
from tqdm import tqdm

date_range2023 = pd.date_range(start="2023-01-01", end="2023-12-31", freq="D")
date_range2022 = pd.date_range(start="2022-01-01", end="2022-12-31", freq="D")
date_range2021 = pd.date_range(start="2021-01-01", end="2021-12-31", freq="D")
north_provinces = {
    "เชียงราย": {
        "เมืองเชียงราย": ["รอบเวียง", "เวียง", "ท่าสาย"],
        "แม่สาย": ["เวียงพางคำ", "โป่งงาม"],
        "แม่จัน": ["จันจว้า", "ศรีค้ำ"],
        "เชียงของ": ["เวียง", "ครึ่ง"],
        "เวียงป่าเป้า": ["เวียง", "ป่าแดด"],
    },
    "เชียงใหม่": {
        "เมืองเชียงใหม่": ["พระสิงห์", "ศรีภูมิ"],
        "ดอยสะเก็ด": ["ตลาดขวัญ", "เชิงดอย"],
        "สันทราย": ["สันทรายหลวง", "สันพระเนตร"],
        "แม่ริม": ["ริมใต้", "ริมเหนือ"],
        "ฝาง": ["เวียง", "แม่สูน"],
    },
    "ลำพูน": {
        "เมืองลำพูน": ["ในเมือง", "เหมืองง่า"],
        "ป่าซาง": ["ป่าซาง", "มะกอก"],
        "บ้านธิ": ["บ้านธิ", "ห้วยยาบ"],
        "ลี้": ["ลี้", "นาทราย"],
    },
    "ลำปาง": {
        "เมืองลำปาง": ["หัวเวียง", "สบตุ๋ย"],
        "เกาะคา": ["เกาะคา", "ศาลา"],
        "เถิน": ["เถินบุรี", "แม่ถอด"],
        "แม่ทะ": ["แม่ทะ", "นาครัว"],
    },
    "น่าน": {
        "เมืองน่าน": ["ในเวียง", "บ่อ"],
        "ปัว": ["ปัว", "ศิลาแลง"],
        "ท่าวังผา": ["ท่าวังผา", "ยม"],
        "เวียงสา": ["กลางเวียง", "ไหล่น่าน"],
    },
    "พะเยา": {
        "เมืองพะเยา": ["เวียง", "แม่ต๋ำ"],
        "เชียงคำ": ["เวียง", "หย่วน"],
        "เชียงม่วน": ["เชียงม่วน", "บ้านมาง"],
        "จุน": ["จุน", "หงส์หิน"],
    },
    "แพร่": {
        "เมืองแพร่": ["ในเวียง", "นาจักร"],
        "ร้องกวาง": ["ร้องกวาง", "น้ำเลา"],
        "ลอง": ["ห้วยอ้อ", "บ้านปิน"],
        "สูงเม่น": ["สูงเม่น", "น้ำชำ"],
    },
    "แม่ฮ่องสอน": {
        "เมืองแม่ฮ่องสอน": ["จองคำ", "ปางหมู"],
        "ปาย": ["เวียงใต้", "เวียงเหนือ"],
        "แม่สะเรียง": ["แม่สะเรียง", "บ้านกาศ"],
        "ขุนยวม": ["ขุนยวม", "แม่เงา"],
    },
    "อุตรดิตถ์": {
        "เมืองอุตรดิตถ์": ["ท่าอิฐ", "ท่าเสา"],
        "ท่าปลา": ["ท่าปลา", "น้ำหมัน"],
        "น้ำปาด": ["น้ำปาด", "แสนตอ"],
        "ฟากท่า": ["ฟากท่า", "สองคอน"],
    }

}

# %%
records = []
for province, Districts in tqdm(north_provinces.items(), desc="Processing provinces"):
    for District, Subdistricts in Districts.items():
        for Subdistrict in Subdistricts:
            for date in date_range2023:
                records.append({
                    "date": date.strftime("%d/%m/%Y"),
                    "Province": province,
                    "District": District,
                    "Subdistrict": Subdistrict,
                    "Label":0
                })

dataframe_2023 = pd.DataFrame(records)
dataframe_2023
# Out:
# Processing provinces: 100%|██████████| 9/9 [00:00<00:00, 29.44it/s]
#              date   Province       District Subdistrict  Label
# 0      01/01/2023   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 1      02/01/2023   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 2      03/01/2023   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 3      04/01/2023   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 4      05/01/2023   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# ...           ...        ...            ...         ...    ...
# 28100  27/12/2023  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28101  28/12/2023  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28102  29/12/2023  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28103  30/12/2023  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28104  31/12/2023  อุตรดิตถ์         ฟากท่า      สองคอน      0
#
# [28105 rows x 5 columns]

# %%
records = []
for province, Districts in tqdm(north_provinces.items(), desc="Processing provinces"):
    for District, Subdistricts in Districts.items():
        for Subdistrict in Subdistricts:
            for date in date_range2022:
                records.append({
                    "date": date.strftime("%d/%m/%Y"),
                    "Province": province,
                    "District": District,
                    "Subdistrict": Subdistrict,
                    "Label":0
                })

dataframe_2022 = pd.DataFrame(records)
dataframe_2022
# Out:
# Processing provinces: 100%|██████████| 9/9 [00:00<00:00, 26.03it/s]
#              date   Province       District Subdistrict  Label
# 0      01/01/2022   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 1      02/01/2022   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 2      03/01/2022   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 3      04/01/2022   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 4      05/01/2022   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# ...           ...        ...            ...         ...    ...
# 28100  27/12/2022  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28101  28/12/2022  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28102  29/12/2022  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28103  30/12/2022  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28104  31/12/2022  อุตรดิตถ์         ฟากท่า      สองคอน      0
#
# [28105 rows x 5 columns]

# %%
records = []
for province, Districts in tqdm(north_provinces.items(), desc="Processing provinces"):
    for District, Subdistricts in Districts.items():
        for Subdistrict in Subdistricts:
            for date in date_range2021:
                records.append({
                    "date": date.strftime("%d/%m/%Y"),
                    "Province": province,
                    "District": District,
                    "Subdistrict": Subdistrict,
                    "Label":0
                })

dataframe_2021 = pd.DataFrame(records)
dataframe_2021
# Out:
# Processing provinces: 100%|██████████| 9/9 [00:00<00:00, 25.97it/s]
#              date   Province       District Subdistrict  Label
# 0      01/01/2021   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 1      02/01/2021   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 2      03/01/2021   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 3      04/01/2021   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# 4      05/01/2021   เชียงราย  เมืองเชียงราย    รอบเวียง      0
# ...           ...        ...            ...         ...    ...
# 28100  27/12/2021  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28101  28/12/2021  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28102  29/12/2021  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28103  30/12/2021  อุตรดิตถ์         ฟากท่า      สองคอน      0
# 28104  31/12/2021  อุตรดิตถ์         ฟากท่า      สองคอน      0
#
# [28105 rows x 5 columns]

# %%
dataframe_2023.sort_values(by="date").reset_index(drop=True).to_csv("data/dataframe_2023.csv", index=False, encoding="utf-8-sig")
dataframe_2022.sort_values(by="date").reset_index(drop=True).to_csv("data/dataframe_2022.csv", index=False, encoding="utf-8-sig")
dataframe_2021.sort_values(by="date").reset_index(drop=True).to_csv("data/dataframe_2021.csv", index=False, encoding="utf-8-sig")
